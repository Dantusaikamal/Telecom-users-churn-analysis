# %% [markdown]
# ![image](https://github.com/IBM/watson-machine-learning-samples/raw/master/cloud/notebooks/headers/AutoAI-Banner_Experiment-Notebook.png)
# # Experiment Notebook - AutoAI Notebook v1.15.0
#
#
# This notebook contains the steps and code to demonstrate support of AutoAI experiments in Watson Machine Learning service. It introduces Python SDK commands for data retrieval, training experiments, persisting pipelines, testing pipelines, refining pipelines, and scoring the resulting model.
#
# **Note:** Notebook code generated using AutoAI will execute successfully. If code is modified or reordered, there is no guarantee it will successfully execute. For details, see: <a href="https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/autoai-notebook.html">Saving an Auto AI experiment as a notebook</a>

# %% [markdown]
# Some familiarity with Python is helpful. This notebook uses Python 3.7 and `ibm_watson_machine_learning` package.
#
#
# ## Notebook goals
#
# The learning goals of this notebook are:
# -  Defining an AutoAI experiment
# -  Training AutoAI models
# -  Comparing trained models
# -  Deploying the model as a web service
# -  Scoring the model to generate predictions.
#
#
#
# ## Contents
#
# This notebook contains the following parts:
#
# **[Setup](#setup)**<br>
# &nbsp;&nbsp;[Package installation](#install)<br>
# &nbsp;&nbsp;[Watson Machine Learning connection](#connection)<br>
# **[Experiment configuration](#configuration)**<br>
# &nbsp;&nbsp;[Experiment metadata](#metadata)<br>
# **[Working with completed AutoAI experiment](#work)**<br>
# &nbsp;&nbsp;[Get fitted AutoAI optimizer](#get)<br>
# &nbsp;&nbsp;[Pipelines comparison](#comparison)<br>
# &nbsp;&nbsp;[Get pipeline as scikit-learn pipeline model](#get_pipeline)<br>
# &nbsp;&nbsp;[Inspect pipeline](#inspect_pipeline)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[Visualize pipeline model](#visualize)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[Preview pipeline model as python code](#preview)<br>
# **[Deploy and Score](#scoring)**<br>
# &nbsp;&nbsp;[Working with spaces](#working_spaces)<br>
# **[Running AutoAI experiment with Python SDK](#run)**<br>
# **[Clean up](#cleanup)**<br>
# **[Next steps](#next_steps)**<br>
# **[Copyrights](#copyrights)**

# %% [markdown]
# <a id="setup"></a>
# # Setup

# %% [markdown]
# <a id="install"></a>
# ## Package installation
# Before you use the sample code in this notebook, install the following packages:
#  - ibm_watson_machine_learning,
#  - autoai-libs,
#  - lale,
#  - scikit-learn,
#  - xgboost,
#  - lightgbm.

# %%
# !pip install ibm-watson-machine-learning 
# !pip install -U autoai-libs==1.12.7 
# !pip install -U 'lale>=0.5.1,<0.6' 
# !pip install -U scikit-learn==0.23.2 
# !pip install -U xgboost==1.3.3 
# !pip install -U lightgbm==3.1.1
# Out:
# Requirement already satisfied: ibm-watson-machine-learning in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (1.0.45)
# Requirement already satisfied: ibm-cos-sdk==2.7.* in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from ibm-watson-machine-learning) (2.7.0)
# Requirement already satisfied: certifi in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from ibm-watson-machine-learning) (2021.5.30)
# Requirement already satisfied: requests in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from ibm-watson-machine-learning) (2.25.1)
# Requirement already satisfied: tabulate in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from ibm-watson-machine-learning) (0.8.9)
# Requirement already satisfied: urllib3 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from ibm-watson-machine-learning) (1.26.4)
# Requirement already satisfied: pandas<=1.0.5 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from ibm-watson-machine-learning) (1.0.5)
# Requirement already satisfied: lomond in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from ibm-watson-machine-learning) (0.3.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from ibm-cos-sdk==2.7.*->ibm-watson-machine-learning) (0.10.0)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.7.0 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from ibm-cos-sdk==2.7.*->ibm-watson-machine-learning) (2.7.0)
# Requirement already satisfied: ibm-cos-sdk-core==2.7.0 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from ibm-cos-sdk==2.7.*->ibm-watson-machine-learning) (2.7.0)
# Requirement already satisfied: docutils<0.16,>=0.10 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from ibm-cos-sdk-core==2.7.0->ibm-cos-sdk==2.7.*->ibm-watson-machine-learning) (0.15.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from ibm-cos-sdk-core==2.7.0->ibm-cos-sdk==2.7.*->ibm-watson-machine-learning) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from pandas<=1.0.5->ibm-watson-machine-learning) (2021.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from pandas<=1.0.5->ibm-watson-machine-learning) (1.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from python-dateutil<3.0.0,>=2.1->ibm-cos-sdk-core==2.7.0->ibm-cos-sdk==2.7.*->ibm-watson-machine-learning) (1.15.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from requests->ibm-watson-machine-learning) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from requests->ibm-watson-machine-learning) (2.10)
# Requirement already satisfied: autoai-libs==1.12.7 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (1.12.7)
# Requirement already satisfied: gensim==3.8.3 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from autoai-libs==1.12.7) (3.8.3)
# Requirement already satisfied: scikit-learn<0.24,>=0.20.3 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from autoai-libs==1.12.7) (0.23.2)
# Requirement already satisfied: pandas<1.3,>=0.24.2 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from autoai-libs==1.12.7) (1.0.5)
# Requirement already satisfied: numpy==1.19.2 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from autoai-libs==1.12.7) (1.19.2)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from gensim==3.8.3->autoai-libs==1.12.7) (1.5.4)
# Requirement already satisfied: six>=1.5.0 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from gensim==3.8.3->autoai-libs==1.12.7) (1.15.0)
# Requirement already satisfied: Cython==0.29.14 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from gensim==3.8.3->autoai-libs==1.12.7) (0.29.14)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from gensim==3.8.3->autoai-libs==1.12.7) (5.1.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from pandas<1.3,>=0.24.2->autoai-libs==1.12.7) (2021.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from pandas<1.3,>=0.24.2->autoai-libs==1.12.7) (2.8.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from scikit-learn<0.24,>=0.20.3->autoai-libs==1.12.7) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from scikit-learn<0.24,>=0.20.3->autoai-libs==1.12.7) (2.1.0)
# The system cannot find the file specified.
# Requirement already satisfied: scikit-learn==0.23.2 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (0.23.2)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from scikit-learn==0.23.2) (1.19.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from scikit-learn==0.23.2) (1.0.1)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from scikit-learn==0.23.2) (1.5.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from scikit-learn==0.23.2) (2.1.0)
# Requirement already satisfied: xgboost==1.3.3 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (1.3.3)
# Requirement already satisfied: numpy in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from xgboost==1.3.3) (1.19.2)
# Requirement already satisfied: scipy in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from xgboost==1.3.3) (1.5.4)
# Requirement already satisfied: lightgbm==3.1.1 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (3.1.1)
# Requirement already satisfied: numpy in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from lightgbm==3.1.1) (1.19.2)
# Requirement already satisfied: scipy in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from lightgbm==3.1.1) (1.5.4)
# Requirement already satisfied: wheel in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from lightgbm==3.1.1) (0.36.2)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from lightgbm==3.1.1) (0.23.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from scikit-learn!=0.22.0->lightgbm==3.1.1) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dantu\anaconda3\envs\yields\lib\site-packages (from scikit-learn!=0.22.0->lightgbm==3.1.1) (2.1.0)

# %% [markdown]
# <a id="configuration"></a>
# # Experiment configuration

# %% [markdown]
# <a id="metadata"></a>
# ## Experiment metadata
# This cell defines the metadata for the experiment, including: training_data_reference, training_result_reference, experiment_metadata.

# %%
#@hidden_cell
from ibm_watson_machine_learning.helpers import DataConnection
from ibm_watson_machine_learning.helpers import S3Connection, S3Location

training_data_reference = [DataConnection(
    connection=S3Connection(
        api_key='8MGQXLn_Vv9er3Ww4RuBIzZJd-7Ir8Xz4IKFgcc-E2X2',
        auth_endpoint='https://iam.bluemix.net/oidc/token/',
        endpoint_url='https://s3.eu-geo.objectstorage.softlayer.net'
    ),
        location=S3Location(
        bucket='telcoconsumerchurn-donotdelete-pr-z6aanmrxdbpqcg',
        path='Telco-Customer-Churn.csv'
    )),
]
training_result_reference = DataConnection(
    connection=S3Connection(
        api_key='8MGQXLn_Vv9er3Ww4RuBIzZJd-7Ir8Xz4IKFgcc-E2X2',
        auth_endpoint='https://iam.bluemix.net/oidc/token/',
        endpoint_url='https://s3.eu-geo.objectstorage.softlayer.net'
    ),
    location=S3Location(
        bucket='telcoconsumerchurn-donotdelete-pr-z6aanmrxdbpqcg',
        path='auto_ml/8333b8d1-d61f-4781-a97c-289ffcefaa1c/wml_data/4ec64c50-6f28-4e7e-9448-f3e42734625a/data/automl',
        model_location='auto_ml/8333b8d1-d61f-4781-a97c-289ffcefaa1c/wml_data/4ec64c50-6f28-4e7e-9448-f3e42734625a/data/automl/pre_hpo_d_output/Pipeline1/model.pickle',
        training_status='auto_ml/8333b8d1-d61f-4781-a97c-289ffcefaa1c/wml_data/4ec64c50-6f28-4e7e-9448-f3e42734625a/training-status.json'
    ))

# %%
experiment_metadata = dict(
   prediction_type='classification',
   prediction_column='Churn',
   holdout_size=0.1,
   scoring='accuracy',
   csv_separator=',',
   random_state=33,
   max_number_of_estimators=2,
   training_data_reference=training_data_reference,
   training_result_reference=training_result_reference,
   deployment_url='https://eu-gb.ml.cloud.ibm.com',
   project_id='992cbd02-a9bd-4ae0-a700-7eef966a4da2',
   positive_label='Yes',
   drop_duplicates=True
)

# %% [markdown]
# <a id="connection"></a>
# ## Watson Machine Learning connection
#
# This cell defines the credentials required to work with the Watson Machine Learning service.
#
# **Action** Please provide IBM Cloud apikey following [docs](https://cloud.ibm.com/docs/account?topic=account-userapikey).

# %%
api_key = 'PUT_YOUR_KEY_HERE'

# %%
wml_credentials = {
    "apikey": api_key,
    "url": experiment_metadata['deployment_url']
}

# %% [markdown]
# <a id="work"></a>
#
#
# # Working with completed AutoAI experiment
#
# This cell imports the pipelines generated for the experiment so they can be compared to find the optimal pipeline to save as a model.

# %% [markdown]
# <a id="get"></a>
#
#
# ## Get fitted AutoAI optimizer

# %%
from ibm_watson_machine_learning.experiment import AutoAI

pipeline_optimizer = AutoAI(wml_credentials, project_id=experiment_metadata['project_id']).runs.get_optimizer(metadata=experiment_metadata)
# Out:
# DEPRECATED!! Python 3.6 framework is deprecated and will be removed on Jan 20th, 2021. It will be read-only mode starting Nov 20th, 2020. i.e you won't be able to create new assets using this client. Use Python 3.7 instead. For details, see https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/pm_service_supported_frameworks.html
# ---------------------------------------------------------------------------
# WMLClientError                            Traceback (most recent call last)
# <ipython-input-13-c77c63c9352e> in <module>()
#       1 from ibm_watson_machine_learning.experiment import AutoAI
#       2
# ----> 3 pipeline_optimizer = AutoAI(wml_credentials, project_id=experiment_metadata['project_id']).runs.get_optimizer(metadata=experiment_metadata)
#
# C:\Users\dantu\anaconda3\envs\yields\lib\site-packages\ibm_watson_machine_learning\experiment\autoai\autoai.py in __init__(self, wml_credentials, project_id, space_id)
#     102                 self._workspace = WorkSpace(wml_credentials=wml_credentials.copy(),
#     103                                             project_id=project_id,
# --> 104                                             space_id=space_id)
#     105
#     106             self.project_id = self._workspace.project_id
#
# C:\Users\dantu\anaconda3\envs\yields\lib\site-packages\ibm_watson_machine_learning\workspace\workspace.py in __init__(self, wml_credentials, project_id, space_id)
#      72         # --- end note
#      73
# ---> 74         self.wml_client = APIClient(wml_credentials=self.wml_credentials)
#      75
#      76         if not wml_credentials.get('instance_id'):
#
# C:\Users\dantu\anaconda3\envs\yields\lib\site-packages\ibm_watson_machine_learning\client.py in __init__(self, wml_credentials, project_id)
#     304                     "For details, see https://www.ibm.com/support/knowledgecenter/SSQNUZ_current/wsj/analyze-data/pm_service_supported_frameworks.html")
#     305
# --> 306             self.service_instance = ServiceInstanceNewPlan(self)
#     307             self.volumes = Volume(self)
#     308
#
# C:\Users\dantu\anaconda3\envs\yields\lib\site-packages\ibm_watson_machine_learning\instance_new_plan.py in __init__(self, client)
#      47                                                  self._client.ICP_PLATFORM_SPACES,
#      48                                                  )
# ---> 49         self._client.wml_token = self._create_token()
#      50         self._logger.info(u'Successfully prepared token: ' + self._client.wml_token)
#      51         # ml_repository_client is initialized in repo
#
# C:\Users\dantu\anaconda3\envs\yields\lib\site-packages\ibm_watson_machine_learning\instance_new_plan.py in _create_token(self)
#     222         if not self._client.ICP_PLATFORM_SPACES:
#     223             if self._client._is_IAM():
# --> 224                 return self._get_IAM_token()
#     225             else:
#     226                 raise WMLClientError('apikey for IAM token is not provided in credentials for the client.')
#
# C:\Users\dantu\anaconda3\envs\yields\lib\site-packages\ibm_watson_machine_learning\instance_new_plan.py in _get_IAM_token(self)
#     282             token = response.json().get(u'access_token')
#     283         else:
# --> 284             raise WMLClientError(u'Error during getting IAM Token.', response)
#     285         return token
#
# WMLClientError: Error during getting IAM Token.
# Reason: <Response [400]>

# %% [markdown]
# Use `get_params()`- to retrieve configuration parameters.

# %%
pipeline_optimizer.get_params()

# %% [markdown]
# <a id="comparison"></a>
# ## Pipelines comparison
#
# Use the `summary()` method to list trained pipelines and evaluation metrics information in
# the form of a Pandas DataFrame. You can use the DataFrame to compare all discovered pipelines and select the one you like for further testing.

# %%
summary = pipeline_optimizer.summary()
best_pipeline_name = list(summary.index)[0]
summary

# %% [markdown]
# <a id="get_pipeline"></a>
# ### Get pipeline as scikit-learn pipeline model
#
# After you compare the pipelines, download and save a scikit-learn pipeline model object from the
# AutoAI training job.
#
# **Tip:** If you want to get a specific pipeline you need to pass the pipeline name in:
# ```
# pipeline_optimizer.get_pipeline(pipeline_name=pipeline_name)
# ```

# %%
pipeline_model = pipeline_optimizer.get_pipeline()

# %% [markdown]
# Next, check features importance for selected pipeline.

# %%
pipeline_optimizer.get_pipeline_details()['features_importance']

# %% [markdown]
# **Tip:** If you want to check all model evaluation metrics-details, use:
# ```
# pipeline_optimizer.get_pipeline_details()
# ```

# %% [markdown]
# <a id="inspect_pipeline"></a>
# ## Inspect pipeline

# %% [markdown]
# <a id="visualize"></a>
# ### Visualize pipeline model
#
# Preview pipeline model stages as a graph. Each node's name links to a detailed description of the stage.

# %%
pipeline_model.visualize()

# %% [markdown]
# <a id="preview"></a>
# ### Preview pipeline model as python code
# In the next cell, you can preview the saved pipeline model as a python code.
# You will be able to review the exact steps used to create the model.
#
# **Note:** If you want to get sklearn representation add following parameter to `pretty_print` call: `astype='sklearn'`.

# %%
pipeline_model.pretty_print(combinators=False, ipython_display=True)

# %% [markdown]
# <a id="scoring"></a>
# ## Deploy and Score
#
# In this section you will learn how to deploy and score the model as a web service.

# %% [markdown]
# <a id="working_spaces"></a>
# ### Working with spaces
#
# In this section you will specify a deployment space for organizing the assets for deploying and scoring the model. If you do not have an existing space, you can use [Deployment Spaces Dashboard](https://dataplatform.cloud.ibm.com/ml-runtime/spaces?context=cpdaas) to create a new space, following these steps:
#
# - Click **New Deployment Space**.
# - Create an empty space.
# - Select Cloud Object Storage.
# - Select Watson Machine Learning instance and press **Create**.
# - Copy `space_id` and paste it below.
#
# **Tip**: You can also use the SDK to prepare the space for your work. Learn more [here](https://github.com/IBM/watson-machine-learning-samples/blob/master/notebooks/python_sdk/instance-management/Space%20management.ipynb).
#
# **Action**: assign or update space ID below

# %% [markdown]
# ### Deployment creation

# %%
target_space_id = "PUT_YOUR_TARGET_SPACE_ID_HERE"

from ibm_watson_machine_learning.deployment import WebService
service = WebService(source_wml_credentials=wml_credentials,
                     target_wml_credentials=wml_credentials,
                     source_project_id=experiment_metadata['project_id'],
                     target_space_id=target_space_id)
service.create(
model=best_pipeline_name,
metadata=experiment_metadata,
deployment_name='Best_pipeline_webservice'
)

# %% [markdown]
# Use the `print` method for the deployment object to show basic information about the service:

# %%
print(service)

# %% [markdown]
# To show all available information about the deployment use the `.get_params()` method:

# %%
service.get_params()

# %% [markdown]
# ### Scoring of webservice
# You can make scoring request by calling `score()` on the deployed pipeline.

# %% [markdown]
# If you want to work with the web service in an external Python application,follow these steps to retrieve the service object:
#
#  - Initialize the service by `service = WebService(wml_credentials)`
#  - Get deployment_id by `service.list()` method
#  - Get webservice object by `service.get('deployment_id')` method
#
# After that you can call `service.score()` method.

# %% [markdown]
# ### Deleting deployment
# <a id="cleanup"></a>
# You can delete the existing deployment by calling the `service.delete()` command.
# To list the existing web services, use `service.list()`.

# %% [markdown]
# <a id="run"></a>
#
# ## Running AutoAI experiment with Python SDK

# %% [markdown]
# If you want to run AutoAI experiment using python API follow up the steps decribed below. The experiment settings were generated basing on parameters set on UI.
#  - Go to your COS dashboard.
#  - In Service credentials tab, click New Credential.
#  - Add the inline configuration parameter: `{“HMAC”:true}`, click Add.
# This configuration parameter adds the following section to the instance credentials, (for use later in this notebook):
# ```
# cos_hmac_keys”: {
#       “access_key_id”: “***“,
#       “secret_access_key”: “***”
#  }
#  ```
#
# **Action:** Please provide cos credentials in following cells.
#
# - Use provided markdown cells to run code.

# %% [markdown]
# ```
# from ibm_watson_machine_learning.experiment import AutoAI
#
# experiment = AutoAI(wml_credentials, project_id=experiment_metadata['project_id'])
# ```

# %% [markdown]
# ```
# #@hidden_cell
# cos_hmac_keys = {
#     "access_key_id": "PLACE_YOUR_ACCESS_KEY_ID_HERE",
#     "secret_access_key": "PLACE_YOUR_SECRET_ACCESS_KEY_HERE"
#   }
#
# cos_api_key = "PLACE_YOUR_API_KEY_HERE"
# OPTIMIZER_NAME = 'custom_name'
# ```

# %% [markdown]
# The experiment settings were generated basing on parameters set on UI.

# %% [markdown]
# ```
# from ibm_watson_machine_learning.helpers import DataConnection
# from ibm_watson_machine_learning.helpers import S3Connection, S3Location
#
# training_data_reference = [DataConnection(
#     connection=S3Connection(
#         api_key=cos_api_key,
#         auth_endpoint='https://iam.bluemix.net/oidc/token/',
#         endpoint_url='https://s3.eu-geo.objectstorage.softlayer.net',
#         access_key_id = cos_hmac_keys['access_key_id'],
#         secret_access_key = cos_hmac_keys['secret_access_key']
#     ),
#         location=S3Location(
#         bucket='telcoconsumerchurn-donotdelete-pr-z6aanmrxdbpqcg',
#         path='Telco-Customer-Churn.csv'
#     )),
# ]
# from ibm_watson_machine_learning.helpers import S3Connection, S3Location
# training_result_reference = DataConnection(
#     connection=S3Connection(
#         api_key=cos_api_key,
#         auth_endpoint='https://iam.bluemix.net/oidc/token/',
#         endpoint_url='https://s3.eu-geo.objectstorage.softlayer.net',
#         access_key_id = cos_hmac_keys['access_key_id'],
#         secret_access_key = cos_hmac_keys['secret_access_key']
#     ),
#     location=S3Location(
#         bucket='telcoconsumerchurn-donotdelete-pr-z6aanmrxdbpqcg',
#         path='auto_ml/8333b8d1-d61f-4781-a97c-289ffcefaa1c/wml_data/4ec64c50-6f28-4e7e-9448-f3e42734625a/data/automl',
#         model_location='auto_ml/8333b8d1-d61f-4781-a97c-289ffcefaa1c/wml_data/4ec64c50-6f28-4e7e-9448-f3e42734625a/data/automl/pre_hpo_d_output/Pipeline1/model.pickle',
#         training_status='auto_ml/8333b8d1-d61f-4781-a97c-289ffcefaa1c/wml_data/4ec64c50-6f28-4e7e-9448-f3e42734625a/training-status.json'
#     ))
# ```

# %% [markdown]
# ```
# pipeline_optimizer = experiment.optimizer(
#     name=OPTIMIZER_NAME,
#     prediction_type=experiment_metadata['prediction_type'],
#     prediction_column=experiment_metadata['prediction_column'],
#     scoring=experiment_metadata['scoring'],
#     holdout_size=experiment_metadata['holdout_size'],
#     csv_separator=experiment_metadata['csv_separator'],
#     positive_label=experiment_metadata['positive_label'],
#     drop_duplicates=experiment_metadata['drop_duplicates'])
# ```

# %% [markdown]
# ```
# pipeline_optimizer.fit(training_data_reference=training_data_reference,
#                        training_results_reference=training_result_reference,
#                        background_mode=False)
# ```

# %% [markdown]
# <a id="next_steps"></a>
# # Next steps
#
# #### [Online Documentation](https://www.ibm.com/cloud/watson-studio/autoai)

# %% [markdown]
# <a id="copyrights"></a>
# ### Copyrights
#
# Licensed Materials - Copyright © 2021 IBM. This notebook and its source code are released under the terms of the ILAN License.
# Use, duplication disclosure restricted by GSA ADP Schedule Contract with IBM Corp.
#
# **Note:** The auto-generated notebooks are subject to the International License Agreement for Non-Warranted Programs (or equivalent) and License Information document for Watson Studio Auto-generated Notebook (License Terms), such agreements located in the link below. Specifically, the Source Components and Sample Materials clause included in the License Information document for Watson Studio Auto-generated Notebook applies to the auto-generated notebooks.
#
# By downloading, copying, accessing, or otherwise using the materials, you agree to the <a href="http://www14.software.ibm.com/cgi-bin/weblap/lap.pl?li_formnum=L-AMCU-BYC7LF">License Terms</a>
#
# ___
